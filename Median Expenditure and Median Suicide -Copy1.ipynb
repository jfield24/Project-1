# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import json
import time
from sklearn import preprocessing
import gmaps
import gmaps.datasets
import gmaps.geojson_geometries

from matplotlib.cm import viridis
from matplotlib.colors import to_hex

# Import API key
from api_key import g_key

# %%
descriptives_table = pd.read_csv("./output_data/developed_countries.csv")
country_coordinates = pd.read_csv("./country_co-ordinates.csv")

mean_df = combined_df[['Country', "health expenditure (per capita)", "number of suicides (per 100,000 people)"]]\
                .groupby("Country").mean()
combined_df = descriptives_table.merge(country_coordinates, on="Country", how="left")

mean_df
# descriptives_table.count()[0
# combined_df.sort_values("health expenditure (per capita)")
# Out:
#                 health expenditure (per capita)  \
# Country
# Australia                           4829.850952
# Austria                             4845.377734
# Belgium                             4445.543335
# Cyprus                              1883.281702
# Czech Republic                      1357.324939
# Denmark                             5898.978174
# Estonia                              988.335376
# Finland                             4178.481201
# Germany                             4650.628418
# Greece                              2208.697681
# Iceland                             4380.332935
# Israel                              2257.100122
# Italy                               3155.522217
# Japan                               3895.448755
# Latvia                               765.502203
# Lithuania                            856.958936
# Luxembourg                          6840.001758
# Malta                               1892.489197
# ...

# %%
#Configuring gmaps
gmaps.configure(api_key=g_key)

#Store latitude and longitude in locations
locations = combined_df[["latitude", "longitude"]]

#Store humidity in humidity
expenditure = combined_df["health expenditure (per capita)"]

# %%
# Plotting Heatmap
fig = gmaps.figure(center=(46.0, -5.0), zoom_level=2)
max_intensity = np.max(expenditure)

#Creating heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=expenditure, dissipating=False,
                                     max_intensity=max_intensity, opacity=0.5, point_radius=10)

#Adding layer
fig.add_layer(heat_layer)

#Displaying figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Store humidity in humidity
sucide_rate = combined_df["number of suicides (per 100,000 people)"]

# Plotting Heatmap
fig = gmaps.figure(center=(46.0, -5.0), zoom_level=2)
max_intensity = np.max(sucide_rate)

#Creating heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=sucide_rate, dissipating=False,
                                     max_intensity=max_intensity, opacity=0.3, point_radius=10)

#Adding layer
fig.add_layer(heat_layer)

#Displaying figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
