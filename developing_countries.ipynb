# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import json
import time
import gmaps

from matplotlib.cm import viridis
from matplotlib.colors import to_hex

# Import API key
from api_key import g_key

# %%
developed_countries = pd.read_csv("./output_data/developing_countries.csv")
country_coordinates = pd.read_csv("./country_co-ordinates.csv")

mean_df = developed_countries[['country', "health expenditure (per capita)", "number of suicides (per 100,000 people)"]]\
                .groupby("country").mean()
combined_df = mean_df.merge(country_coordinates, on="country", how="left")
combined_df
# Out:
#                country  health expenditure (per capita)  \
# 0            Argentina                       916.627866
# 1              Armenia                       295.180881
# 2               Belize                       246.690393
# 3               Brazil                       813.399377
# 4    Brunei Darussalam                       783.090271
# 5                Chile                       912.001569
# 6             Colombia                       434.255896
# 7              Croatia                      1018.714990
# 8              Ecuador                       374.946036
# 9            Guatemala                       187.749652
# 10             Hungary                       983.233948
# 11          Kazakhstan                       284.578085
# 12           Mauritius                       378.003966
# 13              Mexico                       551.536526
# 14              Panama                       630.237573
# 15              Poland                       792.100702
# 16               Qatar                      1545.006995
# 17             Romania                       441.807062
# 18  Russian Federation                       600.870148
# 19              Serbia                       561.800134
# 20          Seychelles                       549.000388
# 21        South Africa                       475.769821
# 22            Thailand                       175.636626
# 23        Turkmenistan                       314.220988
#
#     number of suicides (per 100,000 people) country_code   latitude  \
# 0                                  8.044846           AR -38.416097
# 1                                  2.460053           AM  40.069099
# 2                                  6.092898           BZ  17.189877
# 3                                  5.356623           BR -14.235004
# 4                                  1.794287           BN   4.535277
# 5                                 12.095449           CL -35.675147
# 6                                  5.132313           CO   4.570868
# 7                                 18.246614           HR  45.100000
# 8                                  6.766651           EC  -1.831239
# 9                                  3.278453           GT  15.783471
# 10                                24.199124           HU  47.162494
# 11                                24.381996           KZ  48.019573
# 12                                 9.509798           MU -20.348404
# 13                                 4.868738           MX  23.634501
# 14                                 4.692356           PA   8.537981
# 15                                16.511238           PL  51.919438
# 16                                 2.680297           QA  25.354826
# 17                                12.523022           RO  45.943161
# 18                                24.768435           RU  61.524010
# 19                                18.154001           RS  44.016521
# 20                                 6.755961           SC  -4.679574
# 21                                 0.994340           ZA -30.559482
# 22                                 6.413444           TH  15.870032
# 23                                 5.194144           TM  38.969719
#
#      longitude
# 0   -63.616672
# 1    45.038189
# 2   -88.497650
# 3   -51.925280
# 4   114.727669
# 5   -71.542969
# 6   -74.297333
# 7    15.200000
# 8   -78.183406
# 9   -90.230759
# 10   19.503304
# 11   66.923684
# 12   57.552152
# 13 -102.552784
# 14  -80.782127
# 15   19.145136
# 16   51.183884
# 17   24.966760
# 18  105.318756
# 19   21.005859
# 20   55.491977
# 21   22.937506
# 22  100.992541
# 23   59.556278

# %%
#Configuring gmaps
gmaps.configure(api_key=g_key)

#Store latitude and longitude in locations
locations = combined_df[["latitude", "longitude"]]

#Store humidity in humidity
expenditure = combined_df["health expenditure (per capita)"]

# %%
# Plotting Heatmap
fig = gmaps.figure(center=(46.0, -5.0), zoom_level=2)
max_intensity = np.max(expenditure)

#Creating heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=expenditure, dissipating=False,
                                     max_intensity=max_intensity, opacity=0.5, point_radius=10)

#Adding layer
fig.add_layer(heat_layer)

#Displaying figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Number of Suicide 
suicide_rate = combined_df["number of suicides (per 100,000 people)"]

# Plotting Heatmap
fig = gmaps.figure(center=(46.0, -5.0), zoom_level=2)
max_intensity = np.max(suicide_rate)

#Creating heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=suicide_rate, dissipating=False,
                                     max_intensity=max_intensity, opacity=0.5, point_radius=10)

#Adding layer
fig.add_layer(heat_layer)

#Displaying figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
